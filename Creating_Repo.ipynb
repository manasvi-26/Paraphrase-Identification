# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np

# %%
# %cd /content/drive/"My Drive"/IRE/
# !pwd
# Out:
# /content/drive/My Drive/IRE
# /content/drive/My Drive/IRE

# %%
from getpass import getpass
user = getpass('GitHub user')
password = getpass('GitHub password')
os.environ['GITHUB_AUTH'] = user + ':' + password
# !git clone https://github.com/manasvi-26/Paraphrase-Identification.git
# Out:
# GitHub user··········
# GitHub password··········

# %%
# !git config --global user.name manasvi-26
# !git config --global user.email

# %%
# %mv Creating_Repo.ipynb ./Paraphrase-Identification/

# %%
# %cd Paraphrase-Identification/
# Out:
# /content/drive/My Drive/IRE/Paraphrase-Identification

# %%
# !ls
# Out:
# Creating_Repo.ipynb  README.md

# %%
# %cp -r ../fastai-bert-finetuning/glue_data/ .

# %%
# %cp -r ../fastai-bert-finetuning/__pycache__/ .

# %%
# %cp -r ../fastai-bert-finetuning/utils.py .

# %%
# %cp -r ../fastai-bert-finetuning/Testing_Best_Para_Model.ipynb .

# %%
# %cp -r ../fastai-bert-finetuning/requirements.txt .

# %%
# %cp -r ../fastai-bert-finetuning/Paraphrase_Identification_Training_PAWS.ipynb .

# %%
# %cp -r ../fastai-bert-finetuning/Paraphrase_Identification_Training_MRPC.ipynb .

# %%
# %cp -r ../fastai-bert-finetuning/download_glue_data.py .

# %%
# %cp -r ../fastai-bert-finetuning/bert_helper.py .

# %%
# %cp -r ../fastai-bert-finetuning/bert_fastai.py .

# %%
# %cp -r ../fastai-bert-finetuning/XLNET_Paraphrase_identification.ipynb .

# %%
# !ls
# Out:
# bert_fastai.py
# bert_helper.py
# Creating_Repo.ipynb
# download_glue_data.py
# glue_data
# Paraphrase_Identification_Training_MRPC.ipynb
# Paraphrase_Identification_Training_PAWS.ipynb
# __pycache__
# README.md
# requirements.txt
# Testing_Best_Para_Model.ipynb
# utils.py
# XLNET_Paraphrase_identification.ipynb

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	Creating_Repo.ipynb
# 	Paraphrase_Identification_Training_MRPC.ipynb
# 	Paraphrase_Identification_Training_PAWS.ipynb
# 	Testing_Best_Para_Model.ipynb
# 	XLNET_Paraphrase_identification.ipynb
# 	__pycache__/
# 	bert_fastai.py
# 	bert_helper.py
# 	download_glue_data.py
# 	glue_data/
# 	requirements.txt
# 	utils.py
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add -A

# %%
# !git commit -m "added all the files"
# Out:
# [main a2814b1] added all the files
#  19 files changed, 12393 insertions(+)
#  create mode 100644 Creating_Repo.ipynb
#  create mode 100644 Paraphrase_Identification_Training_MRPC.ipynb
#  create mode 100644 Paraphrase_Identification_Training_PAWS.ipynb
#  create mode 100644 Testing_Best_Para_Model.ipynb
#  create mode 100644 XLNET_Paraphrase_identification.ipynb
#  create mode 100644 __pycache__/bert_fastai.cpython-37.pyc
#  create mode 100644 __pycache__/bert_helper.cpython-37.pyc
#  create mode 100644 __pycache__/utils.cpython-37.pyc
#  create mode 100644 bert_fastai.py
#  create mode 100644 bert_helper.py
#  create mode 100644 download_glue_data.py
#  create mode 100644 glue_data/MRPC/dev.tsv
#  create mode 100644 glue_data/MRPC/dev_ids.tsv
#  create mode 100644 glue_data/MRPC/msr_paraphrase_test.txt
#  create mode 100644 glue_data/MRPC/msr_paraphrase_train.txt
#  create mode 100644 glue_data/MRPC/test.tsv
#  create mode 100644 glue_data/MRPC/train.tsv
# ...

# %%
# !git push origin master
# Out:
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://github.com/manasvi-26/Paraphrase-Identification.git'
